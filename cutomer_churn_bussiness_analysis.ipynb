# %% [markdown]
# # Customer Churn Bussiness Analysis

# %% [markdown]
# ### Importing Necessary Libraries

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %% [markdown]
# ### Reading Data and Overview

# %%
# View the first few rows of the dataset
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ### Data Cleaning + EDA

# %%
# to let pandas display all columns
pd.options.display.max_columns = None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import streamlit as st
import joblib


def getInput():

    gender = st.selectbox("Select gender".title(), ["Male", "Female"])

    SeniorCitizen = st.selectbox("Are you a Senior Citizen ?".title(), [0, 1])

    Partner = st.selectbox("Do you have a partner ?".title(), ["Yes", "No"])

    Dependents = st.selectbox("Do you have any Dependents ?".title(), ["Yes", "No"])

    tenure = st.slider(
        "choose tenure (in months)".title(), min_value=0.0, max_value=72.0, step=3.0
    )

    PhoneService = st.selectbox("Do you have PhoneService ?".title(), ["Yes", "No"])

    MultipleLines = st.selectbox(
        "Do you have MultipleLines ?".title(), ["Yes", "No", "No phone service"]
    )

    InternetService = st.selectbox(
        "Select InternetService Type ?".title(), ["Fiber optic", "DSL", "No"]
    )

    OnlineSecurity = st.selectbox(
        "Do you have OnlineSecurity ?".title(), ["Yes", "No", "No internet service"]
    )

    OnlineBackup = st.selectbox(
        "Do you have OnlineBackup ?".title(), ["Yes", "No", "No internet service"]
    )

    DeviceProtection = st.selectbox(
        "Do you have DeviceProtection ?".title(), ["Yes", "No", "No internet service"]
    )

    TechSupport = st.selectbox(
        "Do you have TechSupport ?".title(), ["Yes", "No", "No internet service"]
    )

    StreamingTV = st.selectbox(
        "Do you have StreamingTV ?".title(), ["Yes", "No", "No internet service"]
    )

    StreamingMovies = st.selectbox(
        "Do you have StreamingMovies ?".title(), ["Yes", "No", "No internet service"]
    )

    Contract = st.selectbox(
        "Select Contract Type".title(), ["Month-to-month", "Two year", "One year"]
    )

    PaperlessBilling = st.selectbox(
        "Do you have PaperlessBilling ?".title(), ["Yes", "No"]
    )

    PaymentMethod = st.selectbox(
        "Select Payment Method".title(),
        [
            "Electronic check",
            "Mailed check",
            "Bank transfer (automatic)",
            "Credit card (automatic)",
        ],
    )

    MonthlyCharges = st.slider(
        "Input your MonthlyCharges".title(), min_value=19.0, max_value=117.0, step=10.0
    )

    TotalCharges = st.slider(
        "Input your TotalCharges".title(), min_value=0.0, max_value=8680.0, step=100.0
    )

    return pd.DataFrame(
        data=[
            [
                gender,
                SeniorCitizen,
                Partner,
                Dependents,
                tenure,
                PhoneService,
                MultipleLines,
                InternetService,
                OnlineSecurity,
                OnlineBackup,
                DeviceProtection,
                TechSupport,
                StreamingTV,
                StreamingMovies,
                Contract,
                PaperlessBilling,
                PaymentMethod,
                MonthlyCharges,
                TotalCharges,
            ]
        ],
        columns=[
            "gender",
            "SeniorCitizen",
            "Partner",
            "Dependents",
            "tenure",
            "PhoneService",
            "MultipleLines",
            "InternetService",
            "OnlineSecurity",
            "OnlineBackup",
            "DeviceProtection",
            "TechSupport",
            "StreamingTV",
            "StreamingMovies",
            "Contract",
            "PaperlessBilling",
            "PaymentMethod",
            "MonthlyCharges",
            "TotalCharges",
        ],
    )


test = getInput()
st.dataframe(test)
model = joblib.load("model.h5")

st.write(
    "Yes Customer Churns" if model.predict(test) == 1 else "No Customer Doesnt Churn"
)
# Out:
# 2024-12-12 16:17:23.187 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 16:17:23.189 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 16:17:23.189 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 16:17:23.190 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 16:17:23.190 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# ...

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# Get the shape of the dataset
print(df.shape)
# Out:
# (7043, 21)

# %%
# checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Check for missing values
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# removing the customerID column
df = df.drop(["customerID"], axis=1)

# %%
df["TotalCharges"]
# Out:
# 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038     1990.5
# 7039     7362.9
# 7040     346.45
# 7041      306.6
# 7042     6844.5
# Name: TotalCharges, Length: 7043, dtype: object

# %%
# checking where TotalCharges is ' ' (empty space)
df[df["TotalCharges"] == " "]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
# fixing TotalCharges column datatype and ' ' (empty space) values
df["TotalCharges"] = df["TotalCharges"].replace(" ", 0).astype(float)

# %%
df[df["TotalCharges"] == 0]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
df[df["tenure"] == 0]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %% [markdown]
# ### Bussiness Analysis in relation to churn

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# #### gender

# %%
df["gender"].value_counts(normalize=True) * 100
# Out:
# gender
# Male      50.47565
# Female    49.52435
# Name: proportion, dtype: float64

# %%
df.groupby("gender")["Churn"].value_counts(normalize=True) * 100
# Out:
# gender  Churn
# Female  No       73.079128
#         Yes      26.920872
# Male    No       73.839662
#         Yes      26.160338
# Name: proportion, dtype: float64

# %%
# Calculate the result
result = df.groupby("gender")["Churn"].value_counts(normalize=True) * 100

# Separate results for male and female
male_result = result.xs("Male", level="gender")
female_result = result.xs("Female", level="gender")

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot pie chart for male
ax1.pie(
    male_result.values,
    labels=male_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 16},
)
ax1.set_title("Male Churn Distribution (50.4%)", fontsize=16)

# Plot pie chart for female
ax2.pie(
    female_result.values,
    labels=female_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 16},
)
ax2.set_title("Female Churn Distribution (49.5%)", fontsize=16)

# Layout so plots do not overlap
fig.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# #### SeniorCitizen

# %%
df["SeniorCitizen"].value_counts(normalize=True) * 100
# Out:
# SeniorCitizen
# 0    83.785319
# 1    16.214681
# Name: proportion, dtype: float64

# %%
df.groupby("SeniorCitizen")["Churn"].value_counts(normalize=True) * 100
# Out:
# SeniorCitizen  Churn
# 0              No       76.393832
#                Yes      23.606168
# 1              No       58.318739
#                Yes      41.681261
# Name: proportion, dtype: float64

# %%
result = df.groupby("SeniorCitizen")["Churn"].value_counts(normalize=True) * 100

# Separate results for SeniorCitizen = 0 and SeniorCitizen = 1
senior_0_result = result.xs(0, level="SeniorCitizen")
senior_1_result = result.xs(1, level="SeniorCitizen")

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot pie chart for SeniorCitizen = 0
ax1.pie(
    senior_0_result.values,
    labels=senior_0_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 16},
)
ax1.set_title("Non-Senior Citizen Churn Distribution (83.8%)", fontsize=16)

# Plot pie chart for SeniorCitizen = 1
ax2.pie(
    senior_1_result.values,
    labels=senior_1_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 16},
)
ax2.set_title("Senior Citizen Churn Distribution (16.2%)", fontsize=16)

# Layout so plots do not overlap
fig.tight_layout()

# Display the plot
plt.show()

# %%
# analyzing Senior Citizens that churned
df[(df["SeniorCitizen"] == 1) & (df["Churn"] == "Yes")].groupby("StreamingTV")[
    "Churn"
].value_counts()
# Out:
# StreamingTV          Churn
# No                   Yes      242
# No internet service  Yes        5
# Yes                  Yes      229
# Name: count, dtype: int64

# %%
# Filter the DataFrame for senior citizens who churned
senior_churned = df[(df["SeniorCitizen"] == 1) & (df["Churn"] == "Yes")]

# Group by StreamingTV and count Churn
streaming_tv_churn_counts = senior_churned.groupby("StreamingTV")[
    "Churn"
].value_counts()

print(streaming_tv_churn_counts)
# Out:
# StreamingTV          Churn
# No                   Yes      242
# No internet service  Yes        5
# Yes                  Yes      229
# Name: count, dtype: int64

# %%
# Create a figure with one subplot
fig, ax = plt.subplots(1, 1, figsize=(8, 6))

# Plot pie chart for StreamingTV distribution
wedges, texts, autotexts = ax.pie(
    streaming_tv_churn_counts.values,
    labels=streaming_tv_churn_counts.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 8},
)
ax.set_title("StreamingTV Distribution for Senior Citizens Who Churned")

# Layout so plot fits well
plt.tight_layout()

# Display the plot
plt.show()

# %%
df[(df["SeniorCitizen"] == 1) & (df["Churn"] == "Yes")]["MonthlyCharges"].mean()
# Out:
# 80.71344537815126

# %%
df[(df["SeniorCitizen"] == 1) & (df["Churn"] == "No")]["MonthlyCharges"].mean()
# Out:
# 79.18205705705705

# %%
df["MonthlyCharges"].mean()
# Out:
# 64.76169246059918

# %% [markdown]
# - senior citizens who churned were paying 80.7 (24.7%) more than avg MonthlyCharges 64.7 but close to their peers which was 79.1
#
# - and staying for avg of 21 months compared to the 42 months of their peers and less than the data average which is 32 months

# %%
df[(df["SeniorCitizen"] == 1) & (df["Churn"] == "Yes")]["TotalCharges"].mean()
# Out:
# 1853.7923319327729

# %%
df["TotalCharges"].mean()
# Out:
# 2279.7343035638223

# %%
df[(df["SeniorCitizen"] == 1) & (df["Churn"] == "Yes")]["tenure"].mean()
# Out:
# 21.03361344537815

# %%
df[(df["SeniorCitizen"] == 1) & (df["Churn"] == "No")]["tenure"].mean()
# Out:
# 42.06006006006006

# %%
df["tenure"].mean()
# Out:
# 32.37114865824223

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# #### Partner

# %%
df["Partner"].value_counts(normalize=True) * 100
# Out:
# Partner
# No     51.69672
# Yes    48.30328
# Name: proportion, dtype: float64

# %%
df.groupby("Partner")["Churn"].value_counts(normalize=True) * 100
# Out:
# Partner  Churn
# No       No       67.042021
#          Yes      32.957979
# Yes      No       80.335097
#          Yes      19.664903
# Name: proportion, dtype: float64

# %%
result = df.groupby("Partner")["Churn"].value_counts(normalize=True) * 100

# Separate results for Partner = No and Partner = Yes
partner_no_result = result.xs("No", level="Partner")
partner_yes_result = result.xs("Yes", level="Partner")

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot pie chart for Partner = No
wedges, texts, autotexts = ax1.pie(
    partner_no_result.values,
    labels=partner_no_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 16},
)
ax1.set_title("Non-Partner Churn Distribution (51.7%)", fontsize=16)

# Plot pie chart for Partner = Yes
wedges, texts, autotexts = ax2.pie(
    partner_yes_result.values,
    labels=partner_yes_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 16},
)
ax2.set_title("Partner Churn Distribution (48.3%)", fontsize=16)

# Layout so plots do not overlap
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# #### Dependents

# %%
df["Partner"].value_counts(normalize=True) * 100
# Out:
# Partner
# No     51.69672
# Yes    48.30328
# Name: proportion, dtype: float64

# %%
df.groupby("Dependents")["Churn"].value_counts(normalize=True) * 100
# Out:
# Dependents  Churn
# No          No       68.720860
#             Yes      31.279140
# Yes         No       84.549763
#             Yes      15.450237
# Name: proportion, dtype: float64

# %%
# Assuming df is your DataFrame with the calculated proportions
result = df.groupby("Dependents")["Churn"].value_counts(normalize=True) * 100

# Separate results for Dependents = No and Dependents = Yes
dependents_no_result = result.loc["No"]
dependents_yes_result = result.loc["Yes"]

# Extract values and labels
no_values = dependents_no_result.values.tolist()
yes_values = dependents_yes_result.values.tolist()
labels = dependents_no_result.index.tolist()  # Both should have the same labels

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot pie chart for Dependents = No
ax1.pie(no_values, labels=labels, autopct="%1.1f%%", textprops={"fontsize": 16})
ax1.set_title("Non-Dependent Churn Distribution (51.7%)", fontsize=16)

# Plot pie chart for Dependents = Yes
ax2.pie(yes_values, labels=labels, autopct="%1.1f%%", textprops={"fontsize": 16})
ax2.set_title("Dependent Churn Distribution(48.3%)", fontsize=16)

# Layout so plots do not overlap
plt.tight_layout()

# Display the plot
plt.show()

# %%
df.groupby("Dependents")["Churn"].value_counts()
# Out:
# Dependents  Churn
# No          No       3390
#             Yes      1543
# Yes         No       1784
#             Yes       326
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# #### tenure

# %%
df.groupby("tenure")["Churn"].describe()
# Out:
#        count unique  top freq
# tenure
# 0         11      1   No   11
# 1        613      2  Yes  380
# 2        238      2  Yes  123
# 3        200      2   No  106
# 4        176      2   No   93
# ...      ...    ...  ...  ...
# 68       100      2   No   91
# 69        95      2   No   87
# 70       119      2   No  108
# 71       170      2   No  164
# 72       362      2   No  356
#
# [73 rows x 4 columns]

# %%
# Histogram
plt.figure(figsize=(10, 6))
sns.histplot(df["tenure"], kde=True, bins=20)
plt.title("Distribution of Customer Tenure")
plt.xlabel("Months")
plt.ylabel("Frequency")
plt.show()

# Density plot
plt.figure(figsize=(10, 6))
sns.kdeplot(df["tenure"])
plt.title("Density Plot of Customer Tenure")
plt.xlabel("Months")
plt.ylabel("Density")
plt.show()

# Box plot for tenure distribution
plt.figure(figsize=(10, 6))
sns.boxplot(x=df["tenure"])
plt.title("Box Plot of Customer Tenure")
plt.xlabel("Tenure (months)")
plt.ylabel("")
plt.show()

# Violin plot for tenure distribution
plt.figure(figsize=(10, 6))
sns.violinplot(x=df["tenure"])
plt.title("Violin Plot of Customer Tenure")
plt.xlabel("Tenure (months)")
plt.ylabel("")
plt.show()

# %%
sns.histplot(data=df, x=df["tenure"], hue="Churn")
# Out:
# <Axes: xlabel='tenure', ylabel='Count'>

# %% [markdown]
# #### PhoneService

# %%
df["PhoneService"].value_counts(normalize=True) * 100
# Out:
# PhoneService
# Yes    90.316626
# No      9.683374
# Name: proportion, dtype: float64

# %%
df.groupby("PhoneService")["Churn"].value_counts(normalize=True) * 100
# Out:
# PhoneService  Churn
# No            No       75.073314
#               Yes      24.926686
# Yes           No       73.290363
#               Yes      26.709637
# Name: proportion, dtype: float64

# %%
# Groupby PhoneService and Churn, then count
phone_service_churn_count = df.groupby(["PhoneService", "Churn"]).size()

# Separate results for PhoneService = No and PhoneService = Yes
phone_service_no_result = phone_service_churn_count.xs("No", level="PhoneService")
phone_service_yes_result = phone_service_churn_count.xs("Yes", level="PhoneService")

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot pie chart for PhoneService = No
wedges, texts, autotexts = ax1.pie(
    phone_service_no_result.values,
    labels=phone_service_no_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 16},
)
centre_circle = plt.Circle((0, 0), 0.70, fc="white")
fig.gca().add_artist(centre_circle)
ax1.set_title("No Phone Service Churn Distribution (9.6%)", fontsize=16)

# Plot pie chart for PhoneService = Yes
wedges, texts, autotexts = ax2.pie(
    phone_service_yes_result.values,
    labels=phone_service_yes_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 16},
)
centre_circle = plt.Circle((0, 0), 0.70, fc="white")
fig.gca().add_artist(centre_circle)
ax2.set_title("Yes Phone Service Churn Distribution (90.3%)", fontsize=16)

# Layout so plots do not overlap
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# #### MultipleLines

# %%
df["MultipleLines"].value_counts(normalize=True) * 100
# Out:
# MultipleLines
# No                  48.132898
# Yes                 42.183729
# No phone service     9.683374
# Name: proportion, dtype: float64

# %%
df.groupby("MultipleLines")["Churn"].value_counts(normalize=True) * 100
# Out:
# MultipleLines     Churn
# No                No       74.955752
#                   Yes      25.044248
# No phone service  No       75.073314
#                   Yes      24.926686
# Yes               No       71.390104
#                   Yes      28.609896
# Name: proportion, dtype: float64

# %%
# Groupby MultipleLines and Churn, then count
multiple_lines_churn_count = df.groupby(["MultipleLines", "Churn"]).size()

# Separate results for each MultipleLines category
no_multiple_lines_result = multiple_lines_churn_count.xs("No", level="MultipleLines")
no_phone_service_result = multiple_lines_churn_count.xs(
    "No phone service", level="MultipleLines"
)
yes_multiple_lines_result = multiple_lines_churn_count.xs("Yes", level="MultipleLines")

# Create a figure with three subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))

# Plot pie chart for No Multiple Lines
wedges, texts, autotexts = ax1.pie(
    no_multiple_lines_result.values,
    labels=no_multiple_lines_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax1.set_title("No Multiple Lines Churn Distribution  (48.1%)", fontsize=18)

# Plot pie chart for No Phone Service
wedges, texts, autotexts = ax2.pie(
    no_phone_service_result.values,
    labels=no_phone_service_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax2.set_title("No Phone Service Churn Distribution (9.6%)", fontsize=18)

# Plot pie chart for Yes Multiple Lines
wedges, texts, autotexts = ax3.pie(
    yes_multiple_lines_result.values,
    labels=yes_multiple_lines_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax3.set_title("Yes Multiple Lines Churn Distribution (42.1%)", fontsize=18)

# Layout so plots do not overlap
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# #### InternetService

# %%
df["InternetService"].value_counts(normalize=True) * 100
# Out:
# InternetService
# Fiber optic    43.958540
# DSL            34.374556
# No             21.666903
# Name: proportion, dtype: float64

# %%
df.groupby("InternetService")["Churn"].value_counts(normalize=True) * 100
# Out:
# InternetService  Churn
# DSL              No       81.040892
#                  Yes      18.959108
# Fiber optic      No       58.107235
#                  Yes      41.892765
# No               No       92.595020
#                  Yes       7.404980
# Name: proportion, dtype: float64

# %%
# Groupby InternetService and Churn, then count
internet_service_churn_count = df.groupby(["InternetService", "Churn"]).size()

# Separate results for each InternetService category
dsl_result = internet_service_churn_count.xs("DSL", level="InternetService")
fiber_optic_result = internet_service_churn_count.xs(
    "Fiber optic", level="InternetService"
)
no_internet_result = internet_service_churn_count.xs("No", level="InternetService")

# Create a figure with three subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))

# Plot pie chart for DSL
wedges, texts, autotexts = ax1.pie(
    dsl_result.values,
    labels=dsl_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax1.set_title("DSL Internet Service Churn Distribution (34.4%)", fontsize=16)

# Plot pie chart for Fiber Optic
wedges, texts, autotexts = ax2.pie(
    fiber_optic_result.values,
    labels=fiber_optic_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax2.set_title("Fiber Optic Internet Service Churn Distribution (44%)", fontsize=16)

# Plot pie chart for No Internet
wedges, texts, autotexts = ax3.pie(
    no_internet_result.values,
    labels=no_internet_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax3.set_title("No Internet Service Churn Distribution (21.6%)", fontsize=16)

# Layout so plots do not overlap
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# #### OnlineSecurity

# %%
df["OnlineSecurity"].value_counts(normalize=True) * 100
# Out:
# OnlineSecurity
# No                     49.666335
# Yes                    28.666761
# No internet service    21.666903
# Name: proportion, dtype: float64

# %%
df.groupby("OnlineSecurity")["Churn"].value_counts(normalize=True) * 100
# Out:
# OnlineSecurity       Churn
# No                   No       58.233276
#                      Yes      41.766724
# No internet service  No       92.595020
#                      Yes       7.404980
# Yes                  No       85.388806
#                      Yes      14.611194
# Name: proportion, dtype: float64

# %%
# Groupby OnlineSecurity and Churn, then count
online_security_churn_count = df.groupby(["OnlineSecurity", "Churn"]).size()

# Separate results for each OnlineSecurity category
no_security_result = online_security_churn_count.xs("No", level="OnlineSecurity")
no_internet_result = online_security_churn_count.xs(
    "No internet service", level="OnlineSecurity"
)
yes_security_result = online_security_churn_count.xs("Yes", level="OnlineSecurity")

# Create a figure with three subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))

# Plot pie chart for No Online Security
wedges, texts, autotexts = ax1.pie(
    no_security_result.values,
    labels=no_security_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax1.set_title("No Online Security Churn Distribution (49.6%)", fontsize=16)

# Plot pie chart for No Internet Service
wedges, texts, autotexts = ax2.pie(
    no_internet_result.values,
    labels=no_internet_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax2.set_title("No Internet Service Churn Distribution (21.6%)", fontsize=16)

# Plot pie chart for Yes Online Security
wedges, texts, autotexts = ax3.pie(
    yes_security_result.values,
    labels=yes_security_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax3.set_title("Yes Online Security Churn Distribution (28.6%)", fontsize=16)

# Layout so plots do not overlap
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# #### OnlineBackup

# %%
df["OnlineBackup"].value_counts(normalize=True) * 100
# Out:
# OnlineBackup
# No                     43.844952
# Yes                    34.488144
# No internet service    21.666903
# Name: proportion, dtype: float64

# %%
df.groupby("OnlineBackup")["Churn"].value_counts()
# Out:
# OnlineBackup         Churn
# No                   No       1855
#                      Yes      1233
# No internet service  No       1413
#                      Yes       113
# Yes                  No       1906
#                      Yes       523
# Name: count, dtype: int64

# %%
# Groupby OnlineBackup and Churn, then count
online_backup_churn_count = df.groupby(["OnlineBackup", "Churn"]).size()

# Separate results for each OnlineBackup category
no_backup_result = online_backup_churn_count.xs("No", level="OnlineBackup")
no_internet_result = online_backup_churn_count.xs(
    "No internet service", level="OnlineBackup"
)
yes_backup_result = online_backup_churn_count.xs("Yes", level="OnlineBackup")

# Create a figure with three subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))

# Plot pie chart for No Online Backup
wedges, texts, autotexts = ax1.pie(
    no_backup_result.values,
    labels=no_backup_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax1.set_title("No Online Backup Churn Distribution (43.8%)", fontsize=18)

# Plot pie chart for No Internet Service
wedges, texts, autotexts = ax2.pie(
    no_internet_result.values,
    labels=no_internet_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax2.set_title("No Internet Service Churn Distribution (21.6%)", fontsize=18)

# Plot pie chart for Yes Online Backup
wedges, texts, autotexts = ax3.pie(
    yes_backup_result.values,
    labels=yes_backup_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax3.set_title("Yes Online Backup Churn Distribution (34.4%)", fontsize=18)

# Layout so plots do not overlap
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# #### DeviceProtection

# %%
df["DeviceProtection"].value_counts(normalize=True) * 100
# Out:
# DeviceProtection
# No                     43.944342
# Yes                    34.388755
# No internet service    21.666903
# Name: proportion, dtype: float64

# %%
df.groupby("DeviceProtection")["Churn"].value_counts()
# Out:
# DeviceProtection     Churn
# No                   No       1884
#                      Yes      1211
# No internet service  No       1413
#                      Yes       113
# Yes                  No       1877
#                      Yes       545
# Name: count, dtype: int64

# %%
# Groupby DeviceProtection and Churn, then count
device_protection_churn_count = df.groupby(["DeviceProtection", "Churn"]).size()

# Separate results for each DeviceProtection category
no_protection_result = device_protection_churn_count.xs("No", level="DeviceProtection")
no_internet_result = device_protection_churn_count.xs(
    "No internet service", level="DeviceProtection"
)
yes_protection_result = device_protection_churn_count.xs(
    "Yes", level="DeviceProtection"
)

# Create a figure with three subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))

# Plot pie chart for No Device Protection
wedges, texts, autotexts = ax1.pie(
    no_protection_result.values,
    labels=no_protection_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax1.set_title("No Device Protection Churn Distribution (43.9%)", fontsize=16)

# Plot pie chart for No Internet Service
wedges, texts, autotexts = ax2.pie(
    no_internet_result.values,
    labels=no_internet_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax2.set_title("No Internet Service Churn Distribution (21.6%)", fontsize=16)

# Plot pie chart for Yes Device Protection
wedges, texts, autotexts = ax3.pie(
    yes_protection_result.values,
    labels=yes_protection_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax3.set_title("Yes Device Protection Churn Distribution (34.3%)", fontsize=16)

# Layout so plots do not overlap
plt.tight_layout()

# Display the plot
plt.show()

# %%
df["DeviceProtection"].value_counts()
# Out:
# DeviceProtection
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: count, dtype: int64

# %%
# exploring why almost 40% of customers that dont have DeviceProtection churn
df[df["DeviceProtection"] == "No"]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 2       Male              0      No         No       2          Yes
# 4     Female              0      No         No       2          Yes
# 6       Male              0      No        Yes      22          Yes
# 7     Female              0      No         No      10           No
# ...      ...            ...     ...        ...     ...          ...
# 7032    Male              1      No         No       1          Yes
# 7033    Male              0      No         No      38          Yes
# 7035    Male              0      No         No      19          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df[df["DeviceProtection"] == "No"].describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    3095.000000  3095.000000     3095.000000   3095.000000
# mean        0.201616    23.696931       70.601050   1798.178966
# std         0.401271    21.760967       20.723009   1872.766296
# min         0.000000     0.000000       23.450000      0.000000
# 25%         0.000000     4.000000       54.300000    262.675000
# 50%         0.000000    17.000000       74.000000   1119.350000
# 75%         0.000000    40.000000       86.050000   2777.575000
# max         1.000000    72.000000      111.250000   7919.800000

# %%
df[(df["DeviceProtection"] == "Yes")].describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    2422.000000  2422.000000     2422.000000   2422.000000
# mean        0.192403    44.604872       84.822254   3913.984269
# std         0.394269    22.968927       20.805755   2377.531812
# min         0.000000     0.000000       29.100000      0.000000
# 25%         0.000000    25.000000       70.012500   1863.125000
# 50%         0.000000    49.000000       88.550000   3924.700000
# 75%         0.000000    66.000000      102.600000   5889.212500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# - customers with no device protection pay on average around 8.25% more (70.6) Monthly Charges than the average customer who pays (64.7).
#
# - However they still pay less on average (70.6) than what a customer with Device Protection pays (84.8)
#
# - Customers with no device protection have average tenure of 23.6 which is 89.0% less than thier peers of average tenure of 44.6 and 37.1% less than the normal average customer which has an average of 32.37

# %% [markdown]
# #### TechSupport

# %%
df["TechSupport"].value_counts(normalize=True) * 100
# Out:
# TechSupport
# No                     49.311373
# Yes                    29.021724
# No internet service    21.666903
# Name: proportion, dtype: float64

# %%
df.groupby("TechSupport")["Churn"].value_counts()
# Out:
# TechSupport          Churn
# No                   No       2027
#                      Yes      1446
# No internet service  No       1413
#                      Yes       113
# Yes                  No       1734
#                      Yes       310
# Name: count, dtype: int64

# %%
# Groupby TechSupport and Churn, then count
tech_support_churn_count = df.groupby(["TechSupport", "Churn"]).size()

# Separate results for each TechSupport category
no_support_result = tech_support_churn_count.xs("No", level="TechSupport")
no_internet_result = tech_support_churn_count.xs(
    "No internet service", level="TechSupport"
)
yes_support_result = tech_support_churn_count.xs("Yes", level="TechSupport")

# Create a figure with three subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))

# Plot pie chart for No Tech Support
wedges, texts, autotexts = ax1.pie(
    no_support_result.values,
    labels=no_support_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax1.set_title("No Tech Support Churn Distribution (49.3%)", fontsize=18)

# Plot pie chart for No Internet Service
wedges, texts, autotexts = ax2.pie(
    no_internet_result.values,
    labels=no_internet_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax2.set_title("No Internet Service Churn Distribution (21.6%)", fontsize=18)

# Plot pie chart for Yes Tech Support
wedges, texts, autotexts = ax3.pie(
    yes_support_result.values,
    labels=yes_support_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax3.set_title("Yes Tech Support Churn Distribution (29%)", fontsize=18)

# Layout so plots do not overlap
plt.tight_layout()

# Display the plot
plt.show()

# %%
df[df["TechSupport"] == "No"].describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    3473.000000  3473.000000     3473.000000   3473.000000
# mean        0.238986    25.844227       74.586683   2089.284927
# std         0.426526    22.608193       21.425092   2077.905707
# min         0.000000     0.000000       23.450000      0.000000
# 25%         0.000000     5.000000       56.100000    329.800000
# 50%         0.000000    19.000000       78.050000   1345.550000
# 75%         0.000000    45.000000       91.700000   3384.000000
# max         1.000000    72.000000      113.200000   8165.100000

# %%
df[df["TechSupport"] == "Yes"].describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    2044.000000  2044.000000     2044.000000   2044.000000
# mean        0.127202    44.822896       80.680137   3810.639555
# std         0.333280    23.185307       22.233865   2404.860863
# min         0.000000     0.000000       28.600000      0.000000
# 25%         0.000000    25.000000       63.887500   1703.937500
# 50%         0.000000    50.000000       81.675000   3768.700000
# 75%         0.000000    67.000000       99.912500   5782.475000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# - customers with no Tech Support pay on average 74.5 monthly charges while their peers with Tech support services pay on average 80.6 put churn less.
#
# - customers with no Tech support have an average tenure of 25.8 months while their peers have 44.8 , which is still less than the data average of 32.3 months

# %% [markdown]
# #### StreamingTV

# %%
df["StreamingTV"].value_counts(normalize=True) * 100
# Out:
# StreamingTV
# No                     39.897771
# Yes                    38.435326
# No internet service    21.666903
# Name: proportion, dtype: float64

# %%
df.groupby("StreamingTV")["Churn"].value_counts(normalize=True) * 100
# Out:
# StreamingTV          Churn
# No                   No       66.476868
#                      Yes      33.523132
# No internet service  No       92.595020
#                      Yes       7.404980
# Yes                  No       69.929812
#                      Yes      30.070188
# Name: proportion, dtype: float64

# %%
# Groupby StreamingTV and Churn, then count
streaming_tv_churn_count = df.groupby(["StreamingTV", "Churn"]).size()

# Separate results for each StreamingTV category
no_streaming_result = streaming_tv_churn_count.xs("No", level="StreamingTV")
no_internet_result = streaming_tv_churn_count.xs(
    "No internet service", level="StreamingTV"
)
yes_streaming_result = streaming_tv_churn_count.xs("Yes", level="StreamingTV")

# Create a figure with three subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))

# Plot pie chart for No Streaming TV
wedges, texts, autotexts = ax1.pie(
    no_streaming_result.values,
    labels=no_streaming_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax1.set_title("No Streaming TV Churn Distribution (39.8%)", fontsize=18)

# Plot pie chart for No Internet Service
wedges, texts, autotexts = ax2.pie(
    no_internet_result.values,
    labels=no_internet_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax2.set_title("No Internet Service Churn Distribution (21.6%)", fontsize=18)

# Plot pie chart for Yes Streaming TV
wedges, texts, autotexts = ax3.pie(
    yes_streaming_result.values,
    labels=yes_streaming_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax3.set_title("Yes Streaming TV Churn Distribution (38.4%)", fontsize=18)

# Layout so plots do not overlap
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# #### StreamingMovies

# %%
df["StreamingMovies"].value_counts(normalize=True) * 100
# Out:
# StreamingMovies
# No                     39.542808
# Yes                    38.790288
# No internet service    21.666903
# Name: proportion, dtype: float64

# %%
df.groupby("StreamingMovies")["Churn"].value_counts(normalize=True) * 100
# Out:
# StreamingMovies      Churn
# No                   No       66.319569
#                      Yes      33.680431
# No internet service  No       92.595020
#                      Yes       7.404980
# Yes                  No       70.058565
#                      Yes      29.941435
# Name: proportion, dtype: float64

# %%
# Assuming df is your DataFrame with the calculated proportions
result = df.groupby("StreamingMovies")["Churn"].value_counts(normalize=True) * 100

# Separate results for each StreamingMovies category
no_movies_result = result.xs("No", level="StreamingMovies")
no_internet_result = result.xs("No internet service", level="StreamingMovies")
yes_movies_result = result.xs("Yes", level="StreamingMovies")

# Create a figure with three subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))

# Plot pie chart for No Streaming Movies
wedges, texts, autotexts = ax1.pie(
    no_movies_result.values,
    labels=no_movies_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax1.set_title("No Streaming Movies Churn Distribution (39.5%)", fontsize=18)

# Plot pie chart for No Internet Service
wedges, texts, autotexts = ax2.pie(
    no_internet_result.values,
    labels=no_internet_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax2.set_title("No Internet Service Churn Distribution (21.6%)", fontsize=18)

# Plot pie chart for Yes Streaming Movies
wedges, texts, autotexts = ax3.pie(
    yes_movies_result.values,
    labels=yes_movies_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax3.set_title("Yes Streaming Movies Churn Distribution (38.7%)", fontsize=18)

# Layout so plots do not overlap
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# #### Contract

# %%
df["Contract"].value_counts(normalize=True) * 100
# Out:
# Contract
# Month-to-month    55.019168
# Two year          24.066449
# One year          20.914383
# Name: proportion, dtype: float64

# %%
df.groupby("Contract")["Churn"].value_counts(normalize=True) * 100
# Out:
# Contract        Churn
# Month-to-month  No       57.290323
#                 Yes      42.709677
# One year        No       88.730482
#                 Yes      11.269518
# Two year        No       97.168142
#                 Yes       2.831858
# Name: proportion, dtype: float64

# %%
# Assuming df is your DataFrame with the calculated proportions
result = df.groupby("Contract")["Churn"].value_counts(normalize=True) * 100

# Separate results for each Contract category
month_to_month_result = result.xs("Month-to-month", level="Contract")
one_year_result = result.xs("One year", level="Contract")
two_year_result = result.xs("Two year", level="Contract")

# Create a figure with three subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))

# Plot pie chart for Month-to-month
wedges, texts, autotexts = ax1.pie(
    month_to_month_result.values,
    labels=month_to_month_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax1.set_title("Month-to-month Contract Churn Distribution (55%)", fontsize=16)

# Plot pie chart for One year
wedges, texts, autotexts = ax2.pie(
    one_year_result.values,
    labels=one_year_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax2.set_title("One year Contract Churn Distribution (20.9%)", fontsize=16)

# Plot pie chart for Two year
wedges, texts, autotexts = ax3.pie(
    two_year_result.values,
    labels=two_year_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 20},
)
ax3.set_title("Two year Contract Churn Distribution (24%)", fontsize=16)

# Layout so plots do not overlap
plt.tight_layout()

# Display the plot
plt.show()

# %%
df["Contract"].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
df[df["Contract"] == "Month-to-month"].describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    3875.000000  3875.000000     3875.000000   3875.000000
# mean        0.208258    18.036645       66.398490   1369.254581
# std         0.406115    17.689054       26.926599   1613.879008
# min         0.000000     1.000000       18.750000     18.850000
# 25%         0.000000     3.000000       45.850000    160.100000
# 50%         0.000000    12.000000       73.250000    679.550000
# 75%         0.000000    29.000000       88.875000   2066.500000
# max         1.000000    72.000000      117.450000   8061.500000

# %%
df[df["Contract"] == "One year"].describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    1473.000000  1473.000000     1473.000000   1473.000000
# mean        0.128988    42.044807       65.048608   3032.622878
# std         0.335301    19.035883       31.840539   2230.374581
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000    27.000000       26.900000    989.050000
# 50%         0.000000    44.000000       68.750000   2656.700000
# 75%         0.000000    58.000000       94.800000   4859.250000
# max         1.000000    72.000000      118.600000   8684.800000

# %%
df[df["Contract"] == "Two year"].describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    1695.000000  1695.000000     1695.000000   1695.000000
# mean        0.085546    56.735103       60.770413   3706.934336
# std         0.279775    18.209363       34.678865   2579.517834
# min         0.000000     0.000000       18.400000      0.000000
# 25%         0.000000    48.000000       24.025000   1269.675000
# 50%         0.000000    64.000000       64.350000   3593.800000
# 75%         0.000000    71.000000       90.450000   5988.800000
# max         1.000000    72.000000      118.750000   8672.450000

# %% [markdown]
# - All customers with different contracts pay on average 60~66 monthly charges.
#
# - Customers with Month-to-month have an average tenure of 18.
#
# - Customers with One year have an average tenure of 42.
#
# - Customers with Two year have an average tenure of 56.

# %%
df.groupby("Contract")["tenure"].mean()
# Out:
# Contract
# Month-to-month    18.036645
# One year          42.044807
# Two year          56.735103
# Name: tenure, dtype: float64

# %%
import matplotlib.pyplot as plt

# Calculate average tenure for each contract type
avg_tenure_by_contract = df.groupby("Contract")["tenure"].mean()

# Create a figure with one subplot
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

# Plot bar chart for average tenure by contract
avg_tenure_by_contract.plot(kind="bar", ax=ax)
ax.set_title("Average Tenure by Contract Type")
ax.set_xlabel("Contract Type")
ax.set_ylabel("Average Tenure (months)")

# Layout so plot fits well
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate average tenure for each contract type
avg_tenure_by_contract = df.groupby("Contract")["tenure"].mean()

# Create a figure with one subplot
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

# Plot bar chart for average tenure by contract
avg_tenure_by_contract.plot(kind="bar", ax=ax)
ax.set_title("Average Tenure by Contract Type")
ax.set_xlabel("Contract Type")
ax.set_ylabel("Average Tenure (months)")

# Add text annotations for each bar
for i, v in enumerate(avg_tenure_by_contract):
    ax.text(i, v + 1, f"{v:.1f}", ha="center", va="bottom", fontsize=8)

# Layout so plot fits well
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# #### PaperlessBilling

# %%
df["PaperlessBilling"].value_counts(normalize=True) * 100
# Out:
# PaperlessBilling
# Yes    59.221922
# No     40.778078
# Name: proportion, dtype: float64

# %%
df.groupby("PaperlessBilling")["Churn"].value_counts(normalize=True) * 100
# Out:
# PaperlessBilling  Churn
# No                No       83.669916
#                   Yes      16.330084
# Yes               No       66.434908
#                   Yes      33.565092
# Name: proportion, dtype: float64

# %%
# Groupby PaperlessBilling and Churn, then count
paperless_billing_churn_count = df.groupby(["PaperlessBilling", "Churn"]).size()

# Separate results for PaperlessBilling = No and PaperlessBilling = Yes
no_paperless_result = paperless_billing_churn_count.xs("No", level="PaperlessBilling")
yes_paperless_result = paperless_billing_churn_count.xs("Yes", level="PaperlessBilling")

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot pie chart for No Paperless Billing
wedges, texts, autotexts = ax1.pie(
    no_paperless_result.values,
    labels=no_paperless_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 16},
)
ax1.set_title("No Paperless Billing Churn Distribution (40.7%)", fontsize=16)

# Plot pie chart for Yes Paperless Billing
wedges, texts, autotexts = ax2.pie(
    yes_paperless_result.values,
    labels=yes_paperless_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 16},
)
ax2.set_title("Yes Paperless Billing Churn Distribution (59.2%)", fontsize=16)

# Layout so plots do not overlap
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# #### PaymentMethod

# %%
df["PaymentMethod"].value_counts(normalize=True) * 100
# Out:
# PaymentMethod
# Electronic check             33.579441
# Mailed check                 22.887974
# Bank transfer (automatic)    21.922476
# Credit card (automatic)      21.610109
# Name: proportion, dtype: float64

# %%
df.groupby("PaymentMethod")["Churn"].value_counts(normalize=True) * 100
# Out:
# PaymentMethod              Churn
# Bank transfer (automatic)  No       83.290155
#                            Yes      16.709845
# Credit card (automatic)    No       84.756899
#                            Yes      15.243101
# Electronic check           No       54.714588
#                            Yes      45.285412
# Mailed check               No       80.893300
#                            Yes      19.106700
# Name: proportion, dtype: float64

# %%
# Assuming df is your DataFrame with the calculated proportions
result = df.groupby("PaymentMethod")["Churn"].value_counts(normalize=True) * 100

# Separate results for each PaymentMethod category
bank_transfer_result = result.xs("Bank transfer (automatic)", level="PaymentMethod")
credit_card_result = result.xs("Credit card (automatic)", level="PaymentMethod")
electronic_check_result = result.xs("Electronic check", level="PaymentMethod")
mailed_check_result = result.xs("Mailed check", level="PaymentMethod")

# Create a figure with four subplots
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 6))

# Plot pie chart for Bank transfer (automatic)
wedges, texts, autotexts = ax1.pie(
    bank_transfer_result.values,
    labels=bank_transfer_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 18},
)
ax1.set_title("Bank transfer (automatic (21.9%)", fontsize=18)

# Plot pie chart for Credit card (automatic)
wedges, texts, autotexts = ax2.pie(
    credit_card_result.values,
    labels=credit_card_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 18},
)
ax2.set_title("Credit card (automatic) (21.6%)", fontsize=18)

# Plot pie chart for Electronic check
wedges, texts, autotexts = ax3.pie(
    electronic_check_result.values,
    labels=electronic_check_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 18},
)
ax3.set_title("Electronic check (33.5%)", fontsize=18)

# Plot pie chart for Mailed check
wedges, texts, autotexts = ax4.pie(
    mailed_check_result.values,
    labels=mailed_check_result.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 18},
)
ax4.set_title("Mailed check (22.8%)", fontsize=18)

# Layout so plots do not overlap
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# #### MonthlyCharges

# %%
df.groupby("Churn")["MonthlyCharges"].count()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: MonthlyCharges, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df["MonthlyCharges"], kde=True, bins=20)
plt.title("Distribution of Monthly Charges")
plt.xlabel("Monthly Charges")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(10, 6))
sns.kdeplot(df["MonthlyCharges"])
plt.title("Density Plot of Monthly Charges")
plt.xlabel("Monthly Charges")
plt.ylabel("Density")
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x=df["MonthlyCharges"])
plt.title("Box Plot of Monthly Charges")
plt.xlabel("Monthly Charges")
plt.ylabel("")
plt.show()

plt.figure(figsize=(10, 6))
sns.violinplot(x=df["MonthlyCharges"])
plt.title("Violin Plot of Monthly Charges")
plt.xlabel("Monthly Charges")
plt.ylabel("")
plt.show()

sns.histplot(data=df, x=df["MonthlyCharges"], hue="Churn")
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='Count'>

# %% [markdown]
# #### TotalCharges

# %%
df.groupby("Churn")["TotalCharges"].count()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: TotalCharges, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df["TotalCharges"], kde=True, bins=20)
plt.title("Distribution of Total Charges")
plt.xlabel("Total Charges")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(10, 6))
sns.kdeplot(df["TotalCharges"])
plt.title("Density Plot of Total Charges")
plt.xlabel("Total Charges")
plt.ylabel("Density")
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x=df["TotalCharges"])
plt.title("Box Plot of Total Charges")
plt.xlabel("Total Charges")
plt.ylabel("")
plt.show()

plt.figure(figsize=(10, 6))
sns.violinplot(x=df["TotalCharges"])
plt.title("Violin Plot of Total Charges")
plt.xlabel("Total Charges")
plt.ylabel("")
plt.show()

sns.histplot(data=df, x=df["TotalCharges"], hue="Churn")
# Out:
# <Axes: xlabel='TotalCharges', ylabel='Count'>

# %% [markdown]
# #### Churn

# %%
df["Churn"].value_counts(normalize=True) * 100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
churn_distribution = df["Churn"].value_counts(normalize=True) * 100

fig, ax = plt.subplots(1, 1, figsize=(8, 6))

wedges, texts, autotexts = ax.pie(
    churn_distribution.values,
    labels=churn_distribution.index,
    autopct="%1.1f%%",
    textprops={"fontsize": 12},
)
ax.set_title("Churn Distribution")

plt.tight_layout()

plt.show()

# %%
# Visualization: Payment Method and Churn
sns.countplot(data=df, x="PaymentMethod", hue="Churn")
plt.title("Churn by Payment Method")
plt.xticks(rotation=45)
plt.show()

# %%
results = {}
object_columns = df.select_dtypes(include="object").columns

# Loop through each object column and group by column and Churn
for column in object_columns:
    if column == "Churn":  # Skip Churn column itself as it will be used in grouping
        continue

    # Group by the categorical column and Churn
    grouped = df.groupby([column, "Churn"]).agg(
        Average_Monthly_Charges=("MonthlyCharges", "mean"),
        Average_Tenure=("tenure", "mean"),
    )

    # Save the result
    results[column] = grouped

# Display results
for column, result in results.items():
    print(f"\nResults for {column}:")
    print(result)
# Out:
# Results for gender:
#               Average_Monthly_Charges  Average_Tenure
# gender Churn
# Female No                   61.664908       37.858768
#        Yes                  74.812087       17.004260
# Male   No                   60.876914       37.289524
#        Yes                  74.066989       18.963441
#
# Results for Partner:
#                Average_Monthly_Charges  Average_Tenure
# Partner Churn
# No      No                   57.271856       28.362966
#         Yes                  71.450958       13.176667
# Yes     No                   64.831742       45.793267
#         Yes                  79.805232       26.593423
#
# Results for Dependents:
#                   Average_Monthly_Charges  Average_Tenure
# Dependents Churn
# No         No                   63.465590       35.578761
#            Yes                  74.774141       17.123137
# Yes        No                   57.083744       41.353700
#            Yes                  72.866104       22.030675
#
# ...

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')
